# %%
import pandas as pd

df = pd.read_csv("used_cars.csv")

(df[['price']]
 .agg(['min','max','mean'])
 .T
 .rename(columns={'min':'Min', 'max':'Max', 'mean':'Mean'})
 .style.format({'Min':'{:.0f}', 'Max':'{:.0f}', 'Mean':'{:.2f}'})
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5269f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5269f_level0_col0" class="col_heading level0 col0" >Min</th>
#       <th id="T_5269f_level0_col1" class="col_heading level0 col1" >Max</th>
#       <th id="T_5269f_level0_col2" class="col_heading level0 col2" >Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5269f_level0_row0" class="row_heading level0 row0" >price</th>
#       <td id="T_5269f_row0_col0" class="data row0 col0" >5118</td>
#       <td id="T_5269f_row0_col1" class="data row0 col1" >45400</td>
#       <td id="T_5269f_row0_col2" class="data row0 col2" >13276.71</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_features = ['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
                      'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
                      'peakrpm', 'citympg', 'highwaympg', 'price']

plt.figure(figsize=(12, 8))
for feature in numerical_features:
    plt.subplot(3, 5, numerical_features.index(feature) + 1)
    sns.histplot(data=df[feature], bins=20, kde=True)
    plt.title(feature)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df['price'], bins=20, kde=True)
plt.title('Distribution of Price')
plt.show()

# %%
correlation_matrix = df[numerical_features].corr()
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Car Price Heatmap')
plt.show()

# %%
n = 10
top_car_models = df['CarName'].value_counts().head(n)

plt.figure(figsize=(14, 4))
sns.barplot(x=top_car_models.values, y=top_car_models.index)
plt.title(f'Top {n} Car Models by Frequency')
plt.xlabel('Frequency')
plt.ylabel('Car Model')
plt.tight_layout()
plt.show()
